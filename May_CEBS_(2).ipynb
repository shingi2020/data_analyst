# %% [markdown]
# <a href="https://colab.research.google.com/github/shingi2020/data_analyst/blob/main/May_CEBS_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/content/may_cebs2.xlsx')

# %%
df.head(5)
# Out:
#        today Date of Alert  Province  District     Ward Location Name  \
# 0 2024-05-02    2024-05-02  Bulawayo  Bulawayo  Ward 25         Nketa
# 1 2024-05-02    2024-05-02  Bulawayo  Bulawayo  Ward 25         Nketa
# 2 2024-05-02    2024-05-02  Bulawayo  Bulawayo  Ward 25         Nketa
# 3 2024-05-02    2024-05-02  Bulawayo  Bulawayo  Ward 25         Nketa
# 4 2024-05-02    2024-05-02  Bulawayo  Bulawayo  Ward 25         Nketa
#
#                 A2.05. Location GIS coordinates  \
# 0  -20.20939 28.5359438 1398.8999999999999 6.15
# 1  -20.20939 28.5359438 1398.8999999999999 6.15
# 2  -20.20939 28.5359438 1398.8999999999999 6.15
# 3             -20.2094483 28.5315666 1399.7 8.0
# 4             -20.2094483 28.5315666 1399.7 8.0
#
#    _A2.05. Location GIS coordinates_latitude  \
# 0                                 -20.209390
# 1                                 -20.209390
# 2                                 -20.209390
# 3                                 -20.209448
# 4                                 -20.209448
#
#    _A2.05. Location GIS coordinates_longitude  \
# 0                                   28.535944
# 1                                   28.535944
# 2                                   28.535944
# 3                                   28.531567
# 4                                   28.531567
#
#    _A2.05. Location GIS coordinates_altitude  ...  \
# 0                                     1398.9  ...
# 1                                     1398.9  ...
# 2                                     1398.9  ...
# 3                                     1399.7  ...
# 4                                     1399.7  ...
#
#                                    Event description              Event Type  \
# 0  Reoccurring influenza in a family including a ...  Influenza-Like Illness
# 1  Reoccurring influenza in a family including a ...  Influenza-Like Illness
# 2  Reoccurring influenza in a family including a ...  Influenza-Like Illness
# 3                   Ringworms with sores in a family               Ringworms
# 4                   Ringworms with sores in a family               Ringworms
#
#   How many people were affected  Gender of Affected Age of Affected  \
# 0                           3.0              Female              35
# 1                           3.0              Female              19
# 2                           3.0              Female              -1
# 3                           6.0                Male               5
# 4                           6.0              Female               8
#
#    Age Range Date Reported                               Action Taken  \
# 0      35-44    2024-05-02  All refered to the facility for treatment
# 1      18-24    2024-05-02  All refered to the facility for treatment
# 2   Under 12    2024-05-02  All refered to the facility for treatment
# 3   Under 12    2024-05-02   All referd to the facility for treatment
# 4   Under 12    2024-05-02   All referd to the facility for treatment
#
#         _id  affected_demographics_001._index
# 0  10535877                              3247
# 1  10535877                              3248
# 2  10535877                              3249
# 3  10535879                              3250
# 4  10535879                              3251
#
# [5 rows x 21 columns]

# %%
df.value_counts()
# Out:
# today       Date of Alert  Province  District  Ward    Location Name      A2.05. Location GIS coordinates                   _A2.05. Location GIS coordinates_latitude  _A2.05. Location GIS coordinates_longitude  _A2.05. Location GIS coordinates_altitude  _A2.05. Location GIS coordinates_precision  Event description                                                 Event Type              How many people were affected  Gender of Affected  Age of Affected  Age Range  Date Reported  Action Taken                                                                                                                                                                                                                                 _id       affected_demographics_001._index
# 2024-05-01  2024-05-01     Bulawayo  Bulawayo  Ward 3  Queens Park East   -20.1163747 28.6128981 1343.7 4.866               -20.116375                                 28.612898                                   1343.700000                                4.866                                       Vomiting and diarrhoea                                            Diarrhoea               3.0                            Male                4                Under 12   2024-05-02     Referred to hospital                                                                                                                                                                                                                         10995863  3832                                1
# 2024-05-23  2024-05-23     Bulawayo  Bulawayo  Ward 3  Queens Park East   -20.1158528 28.6137993 1322.6000000000001 4.92    -20.115853                                 28.613799                                   1322.600000                                4.920                                       Diarrhoea                                                         Diarrhoea               3.0                            Male                11               Under 12   2024-05-23     Referred to facility                                                                                                                                                                                                                         11278695  4400                                1
#             2024-05-22     Bulawayo  Bulawayo  Ward 1  Surbubs            -20.1466277 28.6113331 1362.4000244140625 21.763  -20.146628                                 28.611333                                   1362.400024                                21.763                                      Coughing                                                          Influenza-Like Illness  2.0                            Male                7                Under 12   2024-05-23     Advised to give more fluids with the health teacher  inform the community Sister and with draw from the class referred to the clinic                                                                                                         11055629  4076                                1
#             2024-05-23     Bulawayo  Bulawayo  Ward 2  NORTHEND           -20.1206081 28.5979405 1328.300048828125 4.983    -20.120608                                 28.597940                                   1328.300049                                4.983                                       Pre School s\nFACIAL  rash  and  Ringworms                        Rash                    4.0                            Female              3                Under 12   2024-05-23     Reffered to the Clinic                                                                                                                                                                                                                       11082335  4113                                1
#                                                                                                                                                                                                                                                                                                                                                                                                                                    Male                3                Under 12   2024-05-23     Reffered to the Clinic                                                                                                                                                                                                                       11082335  4110                                1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ..
# 2024-05-16  2024-05-16     Bulawayo  Bulawayo  Ward 3  Khumalo            -20.1460148 28.6103979 1341.4 4.416               -20.146015                                 28.610398                                   1341.400000                                4.416                                       Ringworms                                                         Ringworms               4.0                            Female              5                Under 12   2024-05-16     Health education to the teacher advised  to Withdraw from the class referred to the clinic                                                                                                                                                   10892490  3637                                1
#                                                                                                                                                                                                                                                                                                                                                                                                                                    Male                5                Under 12   2024-05-16     Health education to the teacher advised  to Withdraw from the class referred to the clinic                                                                                                                                                   10892490  3635                                1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                        6                Under 12   2024-05-16     Health education to the teacher advised  to Withdraw from the class referred to the clinic                                                                                                                                                   10892490  3634                                1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          3636                                1
# 2024-05-31  2024-06-03     Harare    Harare    Ward 3  Mbare              -17.8609883 31.03156 1479.4 4.983                 -17.860988                                 31.031560                                   1479.400000                                4.983                                       Increase in Sexual transmitted infections in majoburg line mbare  STI Infections          6.0                            Male                42               35-44      2024-06-03     Health educated the infected individualsand held a health education session with the ladies of the night who stays around majoburg lines to use protection(condoms) and to seek medical attention at Ceshar clinic at mbare hostels clinic   11402687  4539                                1
# Name: count, Length: 819, dtype: int64

# %%
#check datatypes of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 853 entries, 0 to 852
# Data columns (total 21 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   today                                       853 non-null    datetime64[ns]
#  1   Date of Alert                               853 non-null    datetime64[ns]
#  2   Province                                    853 non-null    object
#  3   District                                    853 non-null    object
#  4   Ward                                        852 non-null    object
#  5   Location Name                               853 non-null    object
#  6   A2.05. Location GIS coordinates             824 non-null    object
#  7   _A2.05. Location GIS coordinates_latitude   824 non-null    float64
#  8   _A2.05. Location GIS coordinates_longitude  824 non-null    float64
#  9   _A2.05. Location GIS coordinates_altitude   824 non-null    float64
#  10  _A2.05. Location GIS coordinates_precision  824 non-null    float64
#  11  Event description                           853 non-null    object
#  12  Event Type                                  853 non-null    object
#  13  How many people were affected               852 non-null    float64
#  14  Gender of Affected                          853 non-null    object
#  15  Age of Affected                             853 non-null    int64
#  16  Age Range                                   853 non-null    object
#  17  Date Reported                               853 non-null    datetime64[ns]
#  18  Action Taken                                849 non-null    object
#  19  _id                                         853 non-null    int64
#  20  affected_demographics_001._index            853 non-null    int64
# dtypes: datetime64[ns](3), float64(5), int64(3), object(10)
# memory usage: 140.1+ KB

# %%
df.describe()
# Out:
#                                today                  Date of Alert  \
# count                            853                            853
# mean   2024-05-19 03:47:54.091441920  2024-05-19 00:27:00.633059584
# min              2024-05-01 00:00:00            2024-05-01 00:00:00
# 25%              2024-05-14 00:00:00            2024-05-14 00:00:00
# 50%              2024-05-21 00:00:00            2024-05-21 00:00:00
# 75%              2024-05-27 00:00:00            2024-05-27 00:00:00
# max              2024-05-31 00:00:00            2024-06-03 00:00:00
# std                              NaN                            NaN
#
#        _A2.05. Location GIS coordinates_latitude  \
# count                                 824.000000
# mean                                  -20.163596
# min                                   -22.239625
# 25%                                   -20.208711
# 50%                                   -20.133894
# 75%                                   -20.074779
# max                                   -17.854738
# std                                     1.338701
#
#        _A2.05. Location GIS coordinates_longitude  \
# count                                  824.000000
# mean                                    29.460692
# min                                     28.526376
# 25%                                     28.587707
# 50%                                     28.620751
# 75%                                     30.162424
# max                                     31.042725
# std                                      1.011948
#
#        _A2.05. Location GIS coordinates_altitude  \
# count                                  824.00000
# mean                                  1117.59163
# min                                      0.00000
# 25%                                    586.10000
# 50%                                   1333.55000
# 75%                                   1382.90000
# max                                   1488.60000
# std                                    429.15791
#
#        _A2.05. Location GIS coordinates_precision  \
# count                                  824.000000
# mean                                   166.406487
# min                                      3.583000
# 25%                                      4.700000
# 50%                                      4.875000
# 75%                                      5.000000
# max                                   5000.000000
# std                                    824.877139
#
#        How many people were affected  Age of Affected  \
# count                     852.000000       853.000000
# mean                        5.904930        16.582649
# min                         1.000000        -1.000000
# 25%                         3.000000         5.000000
# 50%                         4.000000         8.000000
# 75%                         7.250000        25.000000
# max                        23.000000        89.000000
# std                         4.858672        17.456970
#
#                        Date Reported           _id  \
# count                            853  8.530000e+02
# mean   2024-05-19 01:29:28.347010560  1.101966e+07
# min              2024-04-30 00:00:00  1.053588e+07
# 25%              2024-05-14 00:00:00  1.086173e+07
# 50%              2024-05-21 00:00:00  1.102891e+07
# 75%              2024-05-27 00:00:00  1.120653e+07
# max              2024-06-03 00:00:00  1.154124e+07
# std                              NaN  2.219540e+05
#
#        affected_demographics_001._index
# count                        853.000000
# mean                        3944.403283
# min                         3247.000000
# 25%                         3601.000000
# 50%                         3974.000000
# 75%                         4263.000000
# max                         4756.000000
# std                          373.144057

# %%
df.isnull().sum()
# Out:
# today                                          0
# Date of Alert                                  0
# Province                                       0
# District                                       0
# Ward                                           1
# Location Name                                  0
# A2.05. Location GIS coordinates               29
# _A2.05. Location GIS coordinates_latitude     29
# _A2.05. Location GIS coordinates_longitude    29
# _A2.05. Location GIS coordinates_altitude     29
# _A2.05. Location GIS coordinates_precision    29
# Event description                              0
# Event Type                                     0
# How many people were affected                  1
# Gender of Affected                             0
# Age of Affected                                0
# Age Range                                      0
# Date Reported                                  0
# Action Taken                                   4
# _id                                            0
# affected_demographics_001._index               0
# dtype: int64

# %%
df =df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 852
# Data columns (total 21 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   today                                       819 non-null    datetime64[ns]
#  1   Date of Alert                               819 non-null    datetime64[ns]
#  2   Province                                    819 non-null    object
#  3   District                                    819 non-null    object
#  4   Ward                                        819 non-null    object
#  5   Location Name                               819 non-null    object
#  6   A2.05. Location GIS coordinates             819 non-null    object
#  7   _A2.05. Location GIS coordinates_latitude   819 non-null    float64
#  8   _A2.05. Location GIS coordinates_longitude  819 non-null    float64
#  9   _A2.05. Location GIS coordinates_altitude   819 non-null    float64
#  10  _A2.05. Location GIS coordinates_precision  819 non-null    float64
#  11  Event description                           819 non-null    object
#  12  Event Type                                  819 non-null    object
#  13  How many people were affected               819 non-null    float64
#  14  Gender of Affected                          819 non-null    object
#  15  Age of Affected                             819 non-null    int64
#  16  Age Range                                   819 non-null    object
#  17  Date Reported                               819 non-null    datetime64[ns]
#  18  Action Taken                                819 non-null    object
#  19  _id                                         819 non-null    int64
#  20  affected_demographics_001._index            819 non-null    int64
# dtypes: datetime64[ns](3), float64(5), int64(3), object(10)
# memory usage: 140.8+ KB

# %%
df.plot(kind ='hist', y ='Age of Affected', figsize=(12, 6))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Compare age and Provice of Events

plt.figure(figsize=(12,8))
ax = sns.boxplot(data = df,
                x = 'Province' ,
                y = 'Age of Affected' ,
                palette = 'coolwarm')
# Out:
# <ipython-input-12-5308e6a4d082>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data = df,

# %%
#Plot the Age Range of the Affected by Province
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Province')
plt.xlabel('Province')
plt.ylabel('How many people were affected')
plt.title('Events by Province')
plt.xticks(rotation=45)
plt.show()

# %%
#Plot the Event Type
plt.figure(figsize=(25, 6))
sns.countplot(data=df, x='Event Type')
plt.xlabel('Event Type')
plt.ylabel('How many people were affected')
plt.title('Events Occurances')
plt.xticks(rotation=65)
plt.show()

# %%
df['Event Type'].value_counts()
# Out:
# Event Type
# Influenza-Like Illness           288
# Diarrhoea                        172
# Ringworms                        168
# Rash                              67
# Environmental Hazard              41
# Suspected TB Case                 25
# STI Infections                    11
# Sudden Death of Unknown Cause     10
# Suspected Scabies Case             7
# Suspected Measles Case             6
# Suspected Malaria Case             6
# Dog Bite                           5
# Malaria Positive Case              4
# Suspected Case of Mumps            4
# Positive TB Case                   2
# Unexplained illness                2
# Snake Bite                         1
# Name: count, dtype: int64

# %%
df['Age Range'].value_counts()
# Out:
# Age Range
# Under 12    496
# 18-24       120
# 25-34        59
# 35-44        58
# 45-54        42
# 55-64        28
# Above 65     16
# Name: count, dtype: int64

# %%
#Show Cases in Harare
#Create dataframe for Harare Cases
df_HTown = df[df['Province'].str.contains('Harare')]

# %%
df_HTown
# Out:
#          today Date of Alert Province District     Ward  \
# 173 2024-05-13    2024-05-13   Harare   Harare  Ward 10
# 174 2024-05-13    2024-05-13   Harare   Harare  Ward 10
# 175 2024-05-13    2024-05-13   Harare   Harare  Ward 10
# 176 2024-05-13    2024-05-13   Harare   Harare  Ward 10
# 177 2024-05-13    2024-05-13   Harare   Harare  Ward 10
# ..         ...           ...      ...      ...      ...
# 961 2024-05-31    2024-05-04   Harare   Harare   Ward 3
# 962 2024-05-31    2024-05-04   Harare   Harare   Ward 3
# 963 2024-05-31    2024-05-04   Harare   Harare   Ward 3
# 964 2024-05-30    2024-05-05   Harare   Harare   Ward 4
# 965 2024-05-30    2024-05-05   Harare   Harare   Ward 4
#
#              Location Name                  A2.05. Location GIS coordinates  \
# 173                  Mbare  -17.8580977 31.0362882 1488.6000000000001 4.566
# 174                  Mbare  -17.8580977 31.0362882 1488.6000000000001 4.566
# 175                  Mbare  -17.8580977 31.0362882 1488.6000000000001 4.566
# 176                  Mbare  -17.8580977 31.0362882 1488.6000000000001 4.566
# 177                  Mbare  -17.8580977 31.0362882 1488.6000000000001 4.566
# ..                     ...                                              ...
# 961  Mbarw Nenyere flats\n              -17.8698405 31.0393138 1467.0 4.933
# 962  Mbarw Nenyere flats\n              -17.8698405 31.0393138 1467.0 4.933
# 963  Mbarw Nenyere flats\n              -17.8698405 31.0393138 1467.0 4.933
# 964         Mbare national                 -17.870705 31.0366741 1451.9 5.0
# 965         Mbare national                 -17.870705 31.0366741 1451.9 5.0
#
#      _A2.05. Location GIS coordinates_latitude  \
# 173                                 -17.858098
# 174                                 -17.858098
# 175                                 -17.858098
# 176                                 -17.858098
# 177                                 -17.858098
# ..                                         ...
# 961                                 -17.869840
# 962                                 -17.869840
# 963                                 -17.869840
# 964                                 -17.870705
# 965                                 -17.870705
#
#      _A2.05. Location GIS coordinates_longitude  \
# 173                                   31.036288
# 174                                   31.036288
# 175                                   31.036288
# 176                                   31.036288
# 177                                   31.036288
# ..                                          ...
# 961                                   31.039314
# 962                                   31.039314
# 963                                   31.039314
# 964                                   31.036674
# 965                                   31.036674
#
#      _A2.05. Location GIS coordinates_altitude  ...  \
# 173                                     1488.6  ...
# 174                                     1488.6  ...
# 175                                     1488.6  ...
# 176                                     1488.6  ...
# 177                                     1488.6  ...
# ..                                         ...  ...
# 961                                     1467.0  ...
# 962                                     1467.0  ...
# 963                                     1467.0  ...
# 964                                     1451.9  ...
# 965                                     1451.9  ...
#
#                                      Event description  \
# 173  Suspected Cholera death with more than 20 peop...
# 174  Suspected Cholera death with more than 20 peop...
# 175  Suspected Cholera death with more than 20 peop...
# 176  Suspected Cholera death with more than 20 peop...
# 177  Suspected Cholera death with more than 20 peop...
# ..                                                 ...
# 961                                         Diarrhoea
# 962                                         Diarrhoea
# 963                                         Diarrhoea
# 964                  Increase in common colds and flue
# 965                  Increase in common colds and flue
#
#                   Event Type How many people were affected  \
# 173  Suspected Cholera Death                           8.0
# 174  Suspected Cholera Death                           8.0
# 175  Suspected Cholera Death                           8.0
# 176  Suspected Cholera Death                           8.0
# 177  Suspected Cholera Death                           8.0
# ..                       ...                           ...
# 961                Diarrhoea                           3.0
# 962                Diarrhoea                           3.0
# 963                Diarrhoea                           3.0
# 964         Health Education                           1.0
# 965         Health Education                           1.0
#
#      Gender of Affected Age of Affected  Age Range Date Reported  \
# 173                Male              33      25-34    2024-05-10
# 174              Female              24      18-24    2024-05-10
# 175              Female              32      25-34    2024-05-10
# 176                Male              41      35-44    2024-05-10
# 177              Female              38      35-44    2024-05-10
# ..                  ...             ...        ...           ...
# 961              Female              37      35-44    2024-05-04
# 962              Female              42      35-44    2024-05-04
# 963                Male              17      18-24    2024-05-04
# 964                Male               6   Under 12    2024-05-05
# 965                Male               2   Under 12    2024-05-05
#
#                                           Action Taken       _id  \
# 173  Visited the area to ascertain an outbreak \nRe...  10833605
# 174  Visited the area to ascertain an outbreak \nRe...  10833605
# 175  Visited the area to ascertain an outbreak \nRe...  10833605
# 176  Visited the area to ascertain an outbreak \nRe...  10833605
# 177  Visited the area to ascertain an outbreak \nRe...  10833605
# ..                                                 ...       ...
# 961  Health education on cough etiquette, importanc...  11440961
# 962  Health education on cough etiquette, importanc...  11440961
# 963  Health education on cough etiquette, importanc...  11440961
# 964  Health education on comon cold and wearing of ...  11440963
# 965  Health education on comon cold and wearing of ...  11440963
#
#      affected_demographics_001._index
# 173                              3550
# 174                              3551
# 175                              3552
# 176                              3553
# 177                              3554
# ..                                ...
# 961                              4653
# 962                              4654
# 963                              4655
# 964                              4656
# 965                              4657
#
# [151 rows x 21 columns]

# %%
df_HTown['Location Name'].value_counts()
# Out:
# Location Name
# Mbare                                      50
# Western triangle                           17
# Old Highfield                              16
# Matapi                                     10
# Mbare Flats                                 8
# Mbare Musika                                6
# Mbare national                              6
# Old highfield                               6
# Mbare area                                  5
# Mbare Msika                                 5
# Mbare musika                                4
# Mbarw Nenyere flats\n                       3
# Old High field                              3
# Old highfield                               2
# Zimbabwe ground Machipsa                    2
# new canaan highfield                        2
# Mbare Joburg lines                          2
# Mastones shopping centre Old Highfields     1
# Mbare National                              1
# New Canaan Highfield                        1
# Western Triangle Highfield ( Gazaland)      1
# Name: count, dtype: int64

# %%
df_HTown.columns
# Out:
# Index(['today', 'Date of Alert', 'Province', 'District', 'Ward',
#        'Location Name', 'A2.05. Location GIS coordinates',
#        '_A2.05. Location GIS coordinates_latitude',
#        '_A2.05. Location GIS coordinates_longitude',
#        '_A2.05. Location GIS coordinates_altitude',
#        '_A2.05. Location GIS coordinates_precision', 'Event description',
#        'Event Type', 'How many people were affected', 'Gender of Affected',
#        'Age of Affected', 'Age Range', 'Date Reported', 'Action Taken', '_id',
#        'affected_demographics_001._index'],
#       dtype='object')

# %%
# Rename columns
df.rename(columns={
    '_A2.05. Location GIS coordinates_latitude': 'latitude',
    '_A2.05. Location GIS coordinates_longitude': 'longitude',
    'How many people were affected': 'affected',
    'Gender of Affected': 'gender',
    'Age of Affected': 'age',
    'Event Type': 'event',
    'Location Name': 'Location',
    'Date Reported': 'date'

}, inplace=True)

print(df)
# Out:
#          today Date of Alert  Province  District     Ward           Location  \
# 0   2024-05-02    2024-05-02  Bulawayo  Bulawayo  Ward 25              Nketa
# 1   2024-05-02    2024-05-02  Bulawayo  Bulawayo  Ward 25              Nketa
# 2   2024-05-02    2024-05-02  Bulawayo  Bulawayo  Ward 25              Nketa
# 3   2024-05-02    2024-05-02  Bulawayo  Bulawayo  Ward 25              Nketa
# 4   2024-05-02    2024-05-02  Bulawayo  Bulawayo  Ward 25              Nketa
# ..         ...           ...       ...       ...      ...                ...
# 848 2024-05-31    2024-05-31  Bulawayo  Bulawayo   Ward 3  Queens Park East
# 849 2024-05-31    2024-05-31  Bulawayo  Bulawayo   Ward 3  Queens Park East
# 850 2024-05-31    2024-05-31  Bulawayo  Bulawayo   Ward 3  Queens Park East
# 851 2024-05-31    2024-05-31  Bulawayo  Bulawayo   Ward 3  Queens Park East
# 852 2024-05-31    2024-05-31  Bulawayo  Bulawayo   Ward 3  Queens Park East
#
#                      A2.05. Location GIS coordinates   latitude  longitude  \
# 0       -20.20939 28.5359438 1398.8999999999999 6.15 -20.209390  28.535944
# 1       -20.20939 28.5359438 1398.8999999999999 6.15 -20.209390  28.535944
# 2       -20.20939 28.5359438 1398.8999999999999 6.15 -20.209390  28.535944
# 3                  -20.2094483 28.5315666 1399.7 8.0 -20.209448  28.531567
# 4                  -20.2094483 28.5315666 1399.7 8.0 -20.209448  28.531567
# ..                                               ...        ...        ...
# 848  -20.1158132 28.6138294 1315.1000000000001 4.833 -20.115813  28.613829
# 849  -20.1158132 28.6138294 1315.1000000000001 4.833 -20.115813  28.613829
# 850                -20.1158302 28.6136501 1320.0 5.0 -20.115830  28.613650
# 851                -20.1158302 28.6136501 1320.0 5.0 -20.115830  28.613650
# 852                -20.1158302 28.6136501 1320.0 5.0 -20.115830  28.613650
#
#      _A2.05. Location GIS coordinates_altitude  ...  \
# 0                                       1398.9  ...
# 1                                       1398.9  ...
# 2                                       1398.9  ...
# 3                                       1399.7  ...
# 4                                       1399.7  ...
# ..                                         ...  ...
# 848                                     1315.1  ...
# 849                                     1315.1  ...
# 850                                     1320.0  ...
# 851                                     1320.0  ...
# 852                                     1320.0  ...
#
#                                      Event description  \
# 0    Reoccurring influenza in a family including a ...
# 1    Reoccurring influenza in a family including a ...
# 2    Reoccurring influenza in a family including a ...
# 3                     Ringworms with sores in a family
# 4                     Ringworms with sores in a family
# ..                                                 ...
# 848                                         Ringworms
# 849                                         Ringworms
# 850                                      TB screening
# 851                                      TB screening
# 852                                      TB screening
#
#                       event affected  gender age  Age Range       date  \
# 0    Influenza-Like Illness      3.0  Female  35      35-44 2024-05-02
# 1    Influenza-Like Illness      3.0  Female  19      18-24 2024-05-02
# 2    Influenza-Like Illness      3.0  Female  -1   Under 12 2024-05-02
# 3                 Ringworms      6.0    Male   5   Under 12 2024-05-02
# 4                 Ringworms      6.0  Female   8   Under 12 2024-05-02
# ..                      ...      ...     ...  ..        ...        ...
# 848               Ringworms      5.0    Male   4   Under 12 2024-05-31
# 849               Ringworms      5.0    Male   6   Under 12 2024-05-31
# 850       Suspected TB Case      3.0    Male  11   Under 12 2024-05-31
# 851       Suspected TB Case      3.0  Female  19      18-24 2024-05-31
# 852       Suspected TB Case      3.0  Female  34      25-34 2024-05-31
#
#                                   Action Taken       _id  \
# 0    All refered to the facility for treatment  10535877
# 1    All refered to the facility for treatment  10535877
# 2    All refered to the facility for treatment  10535877
# 3     All referd to the facility for treatment  10535879
# 4     All referd to the facility for treatment  10535879
# ..                                         ...       ...
# 848                      Referred to facility   11541241
# 849                      Referred to facility   11541241
# 850                      Referred to facility   11541242
# 851                      Referred to facility   11541242
# 852                      Referred to facility   11541242
#
#      affected_demographics_001._index
# 0                                3247
# 1                                3248
# 2                                3249
# 3                                3250
# 4                                3251
# ..                                ...
# 848                              4752
# 849                              4753
# 850                              4754
# 851                              4755
# 852                              4756
#
# [819 rows x 21 columns]
# <ipython-input-83-3f121697adb0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='longitude', y='latitude', hue='affected', palette='coolwarm', alpha=0.8)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Spread of Events')
plt.show()

# %%
#Compare age and Provice of Events

plt.figure(figsize=(12,8))
ax = sns.boxplot(data = df,
                x = 'Ward' ,
                y = 'age' ,
                palette = 'coolwarm')
# Out:
# <ipython-input-243-80a5a6b6c3f2>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data = df,

# %%
#Show Events on a Map
# !pip install geopandas
# !pip install --upgrade fiona geopandas
# !pip install -U googlemaps
import geopandas
# !pip install folium matplotlib mapclassify
# !pip install folium
import folium
from folium import plugins
from folium.plugins import MarkerCluster
import matplotlib.pyplot as plt
from IPython.display import IFrame
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.4)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2024.6.2)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.25.2)
# Requirement already satisfied: fiona in /usr/local/lib/python3.10/dist-packages (1.9.6)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Collecting geopandas
#   Downloading geopandas-0.14.4-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona) (2024.6.2)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona) (1.16.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Installing collected packages: geopandas
#   Attempting uninstall: geopandas
#     Found existing installation: geopandas 0.13.2
#     Uninstalling geopandas-0.13.2:
#       Successfully uninstalled geopandas-0.13.2
# Successfully installed geopandas-0.14.4
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from googlemaps) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2024.6.2)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40712 sha256=b71ffa35458f7ababbbf9dcf964fd1fe435f9273dc1c78ffa8d19291c6292a0f
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Collecting mapclassify
#   Downloading mapclassify-2.6.1-py3-none-any.whl (38 kB)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (3.3)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.2.2)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.11.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->mapclassify) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->mapclassify) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.6.2)
# Installing collected packages: mapclassify
# Successfully installed mapclassify-2.6.1
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.6.2)

# %%
from os import popen
import folium
from folium.plugins import MarkerCluster

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
  harare_map = folium.Map(location=[-18.0542, 31.4288], zoom_start=10,tiles = "openstreetmap")

# %%
harare_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa5facd92fcf5e010fad763ce14d1649 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa5facd92fcf5e010fad763ce14d1649&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa5facd92fcf5e010fad763ce14d1649 = L.map(
#                 &quot;map_aa5facd92fcf5e010fad763ce14d1649&quot;,
#                 {
#                     center: [-18.0542, 31.4288],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f85be33a914f4939271077a9d8b0c0a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aa5facd92fcf5e010fad763ce14d1649);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
import pandas as pd
from IPython.display import display


harare_map = folium.Map(location=[-18.0542, 31.4288], zoom_start=10,tiles = "openstreetmap")
#data = df_HTown[["Event Type", "affected", "Location Name","latitude","longitude"]]

    # Add markers for data points
#for index, row in data.iterrows():
       # tooltip = f"Event: {row['Event Type']}, No of Affected: {row['affected']}, Location: {row['Location Name']}"
        #folium.Marker(
          #  location=[row["latitude"], row["longitude"]],
           # popup=row["Location Name"],
          #  tooltip=tooltip,
      #  ).add_to(harare_map)

    # Color the boroughs using Choropleth
        #folium.Choropleth(
        #geo_data=nyc_boroughs,
        #fill_color="blue",
        #fill_opacity=0.2,
#line_opacity=0.2,
  #  ).add_to(harare_map)



# Display the maps in Google Colab

display(harare_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48751330f0da247571260f9ce490b190 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48751330f0da247571260f9ce490b190&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48751330f0da247571260f9ce490b190 = L.map(
#                 &quot;map_48751330f0da247571260f9ce490b190&quot;,
#                 {
#                     center: [-18.0542, 31.4288],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c37ea39a4f507b97cc488ef818027bc9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_48751330f0da247571260f9ce490b190);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_HTown.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 173 to 965
# Data columns (total 21 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   today                                       151 non-null    datetime64[ns]
#  1   Date of Alert                               151 non-null    datetime64[ns]
#  2   Province                                    151 non-null    object
#  3   District                                    151 non-null    object
#  4   Ward                                        151 non-null    object
#  5   Location                                    151 non-null    object
#  6   A2.05. Location GIS coordinates             151 non-null    object
#  7   latitude                                    151 non-null    float64
#  8   longitude                                   151 non-null    float64
#  9   _A2.05. Location GIS coordinates_altitude   151 non-null    float64
#  10  _A2.05. Location GIS coordinates_precision  151 non-null    float64
#  11  Event description                           151 non-null    object
#  12  event                                       118 non-null    object
#  13  affected                                    147 non-null    float64
#  14  gender                                      151 non-null    object
#  15  age                                         151 non-null    int64
#  16  Age Range                                   151 non-null    object
#  17  date                                        151 non-null    datetime64[ns]
#  18  Action Taken                                151 non-null    object
#  19  _id                                         151 non-null    int64
#  20  affected_demographics_001._index            151 non-null    int64
# dtypes: datetime64[ns](3), float64(5), int64(3), object(10)
# memory usage: 26.0+ KB

# %%
df_test = df_HTown[df_HTown['Ward'].str.contains('25')]
df_test
# Out:
#          today Date of Alert Province District     Ward  \
# 182 2024-05-14    2024-05-14   Harare   Harare  Ward 25
# 183 2024-05-14    2024-05-14   Harare   Harare  Ward 25
# 184 2024-05-14    2024-05-14   Harare   Harare  Ward 25
# 185 2024-05-14    2024-05-14   Harare   Harare  Ward 25
# 186 2024-05-14    2024-05-14   Harare   Harare  Ward 25
# 187 2024-05-14    2024-05-14   Harare   Harare  Ward 25
# 188 2024-05-14    2024-05-14   Harare   Harare  Ward 25
# 189 2024-05-14    2024-05-14   Harare   Harare  Ward 25
# 190 2024-05-14    2024-05-14   Harare   Harare  Ward 25
# 368 2024-05-16    2024-05-16   Harare   Harare  Ward 25
# 369 2024-05-16    2024-05-16   Harare   Harare  Ward 25
# 370 2024-05-16    2024-05-16   Harare   Harare  Ward 25
# 371 2024-05-17    2024-05-17   Harare   Harare  Ward 25
# 372 2024-05-17    2024-05-17   Harare   Harare  Ward 25
# 373 2024-05-17    2024-05-17   Harare   Harare  Ward 25
# 374 2024-05-17    2024-05-17   Harare   Harare  Ward 25
# 375 2024-05-17    2024-05-17   Harare   Harare  Ward 25
# 376 2024-05-17    2024-05-17   Harare   Harare  Ward 25
# 377 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 378 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 379 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 380 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 381 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 382 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 383 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 384 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 385 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 386 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 387 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 388 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 389 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 390 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 391 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 392 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 393 2024-05-20    2024-05-20   Harare   Harare  Ward 25
# 394 2024-05-17    2024-05-17   Harare   Harare  Ward 25
#
#                                     Location  \
# 182                            Old Highfield
# 183                            Old Highfield
# 184                            Old Highfield
# 185                            Old Highfield
# 186                            Old Highfield
# 187                            Old Highfield
# 188                            Old Highfield
# 189                            Old Highfield
# 190                            Old Highfield
# 368                           Old High field
# 369                           Old High field
# 370                           Old High field
# 371                            Old Highfield
# 372                            Old Highfield
# 373                            Old Highfield
# 374                            Old Highfield
# 375                            Old Highfield
# 376                            Old Highfield
# 377                         Western triangle
# 378                         Western triangle
# 379                         Western triangle
# 380                         Western triangle
# 381                         Western triangle
# 382                         Western triangle
# 383                         Western triangle
# 384                         Western triangle
# 385                         Western triangle
# 386                         Western triangle
# 387                         Western triangle
# 388                         Western triangle
# 389                         Western triangle
# 390                         Western triangle
# 391                         Western triangle
# 392                         Western triangle
# 393                         Western triangle
# 394  Mastones shopping centre Old Highfields
#
#                    A2.05. Location GIS coordinates   latitude  longitude  \
# 182             -17.8829269 30.9873189 1463.9 4.92 -17.882927  30.987319
# 183             -17.8829269 30.9873189 1463.9 4.92 -17.882927  30.987319
# 184             -17.8829269 30.9873189 1463.9 4.92 -17.882927  30.987319
# 185             -17.8829269 30.9873189 1463.9 4.92 -17.882927  30.987319
# 186             -17.8829269 30.9873189 1463.9 4.92 -17.882927  30.987319
# 187             -17.8829269 30.9873189 1463.9 4.92 -17.882927  30.987319
# 188             -17.8829269 30.9873189 1463.9 4.92 -17.882927  30.987319
# 189             -17.8829269 30.9873189 1463.9 4.92 -17.882927  30.987319
# 190             -17.8829269 30.9873189 1463.9 4.92 -17.882927  30.987319
# 368               -17.8869667 31.000945 1435.3 4.4 -17.886967  31.000945
# 369               -17.8869667 31.000945 1435.3 4.4 -17.886967  31.000945
# 370               -17.8869667 31.000945 1435.3 4.4 -17.886967  31.000945
# 371              -17.8837583 30.9994333 1441.9 4.7 -17.883758  30.999433
# 372              -17.8837583 30.9994333 1441.9 4.7 -17.883758  30.999433
# 373              -17.8837583 30.9994333 1441.9 4.7 -17.883758  30.999433
# 374              -17.8837583 30.9994333 1441.9 4.7 -17.883758  30.999433
# 375              -17.8837583 30.9994333 1441.9 4.7 -17.883758  30.999433
# 376              -17.8837583 30.9994333 1441.9 4.7 -17.883758  30.999433
# 377  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 378  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 379  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 380  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 381  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 382  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 383  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 384  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 385  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 386  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 387  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 388  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 389  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 390  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 391  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 392  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 393  -17.8974383 30.9821417 1448.6999999999998 4.5 -17.897438  30.982142
# 394              -17.8876828 30.9998956 1423.9 5.0 -17.887683  30.999896
#
#      _A2.05. Location GIS coordinates_altitude  ...  \
# 182                                     1463.9  ...
# 183                                     1463.9  ...
# 184                                     1463.9  ...
# 185                                     1463.9  ...
# 186                                     1463.9  ...
# 187                                     1463.9  ...
# 188                                     1463.9  ...
# 189                                     1463.9  ...
# 190                                     1463.9  ...
# 368                                     1435.3  ...
# 369                                     1435.3  ...
# 370                                     1435.3  ...
# 371                                     1441.9  ...
# 372                                     1441.9  ...
# 373                                     1441.9  ...
# 374                                     1441.9  ...
# 375                                     1441.9  ...
# 376                                     1441.9  ...
# 377                                     1448.7  ...
# 378                                     1448.7  ...
# 379                                     1448.7  ...
# 380                                     1448.7  ...
# 381                                     1448.7  ...
# 382                                     1448.7  ...
# 383                                     1448.7  ...
# 384                                     1448.7  ...
# 385                                     1448.7  ...
# 386                                     1448.7  ...
# 387                                     1448.7  ...
# 388                                     1448.7  ...
# 389                                     1448.7  ...
# 390                                     1448.7  ...
# 391                                     1448.7  ...
# 392                                     1448.7  ...
# 393                                     1448.7  ...
# 394                                     1423.9  ...
#
#                                      Event description  \
# 182                                   Persistent cough
# 183                                   Persistent cough
# 184                                   Persistent cough
# 185                                   Persistent cough
# 186                                   Persistent cough
# 187                                   Persistent cough
# 188                                   Persistent cough
# 189                                   Persistent cough
# 190                                   Persistent cough
# 368                                     Church crusade
# 369                                     Church crusade
# 370                                     Church crusade
# 371  Hording of plastic bottles and containers caus...
# 372  Hording of plastic bottles and containers caus...
# 373  Hording of plastic bottles and containers caus...
# 374  Hording of plastic bottles and containers caus...
# 375  Hording of plastic bottles and containers caus...
# 376  Hording of plastic bottles and containers caus...
# 377  Environmental Nuisance ,Accumulation  of  plas...
# 378  Environmental Nuisance ,Accumulation  of  plas...
# 379  Environmental Nuisance ,Accumulation  of  plas...
# 380  Environmental Nuisance ,Accumulation  of  plas...
# 381  Environmental Nuisance ,Accumulation  of  plas...
# 382  Environmental Nuisance ,Accumulation  of  plas...
# 383  Environmental Nuisance ,Accumulation  of  plas...
# 384  Environmental Nuisance ,Accumulation  of  plas...
# 385  Environmental Nuisance ,Accumulation  of  plas...
# 386  Environmental Nuisance ,Accumulation  of  plas...
# 387  Environmental Nuisance ,Accumulation  of  plas...
# 388  Environmental Nuisance ,Accumulation  of  plas...
# 389  Environmental Nuisance ,Accumulation  of  plas...
# 390  Environmental Nuisance ,Accumulation  of  plas...
# 391  Environmental Nuisance ,Accumulation  of  plas...
# 392  Environmental Nuisance ,Accumulation  of  plas...
# 393  Environmental Nuisance ,Accumulation  of  plas...
# 394  Increase in sales of cough mixtures and psycho...
#
#                        event affected  gender age  Age Range       date  \
# 182  Influenza-Like Symptoms      9.0    Male  23      18-24 2024-05-14
# 183  Influenza-Like Symptoms      9.0    Male  44      35-44 2024-05-14
# 184  Influenza-Like Symptoms      9.0    Male  30      25-34 2024-05-14
# 185  Influenza-Like Symptoms      9.0    Male  29      25-34 2024-05-14
# 186  Influenza-Like Symptoms      9.0    Male  50      45-54 2024-05-14
# 187  Influenza-Like Symptoms      9.0    Male  21      18-24 2024-05-14
# 188  Influenza-Like Symptoms      9.0    Male  35      35-44 2024-05-14
# 189  Influenza-Like Symptoms      9.0  Female  65   Above 65 2024-05-14
# 190  Influenza-Like Symptoms      9.0    Male  65   Above 65 2024-05-14
# 368                      NaN      NaN   Other   5   Under 12 2024-05-17
# 369                      NaN      NaN    Male  60      55-64 2024-05-17
# 370                      NaN      NaN  Female  45      45-54 2024-05-17
# 371     Environmental Hazard      6.0  Female  65   Above 65 2024-05-17
# 372     Environmental Hazard      6.0  Female   9   Under 12 2024-05-17
# 373     Environmental Hazard      6.0  Female   7   Under 12 2024-05-17
# 374     Environmental Hazard      6.0    Male  35      35-44 2024-05-17
# 375     Environmental Hazard      6.0  Female  28      25-34 2024-05-17
# 376     Environmental Hazard      6.0  Female   1   Under 12 2024-05-17
# 377                      NaN     14.0  Female  60      55-64 2024-05-20
# 378                      NaN     14.0    Male  68   Above 65 2024-05-20
# 379                      NaN     14.0  Female  44      35-44 2024-05-20
# 380                      NaN     14.0  Female  25      25-34 2024-05-20
# 381                      NaN     14.0  Female   6   Under 12 2024-05-20
# 382                      NaN     14.0    Male  15      18-24 2024-05-20
# 383                      NaN     14.0  Female  22      18-24 2024-05-20
# 384                      NaN     14.0  Female  23      18-24 2024-05-20
# 385                      NaN     14.0  Female   1   Under 12 2024-05-20
# 386                      NaN     14.0  Female   4   Under 12 2024-05-20
# 387                      NaN     14.0  Female  20      18-24 2024-05-20
# 388                      NaN     14.0  Female  16      18-24 2024-05-20
# 389                      NaN     14.0  Female  10   Under 12 2024-05-20
# 390                      NaN     14.0  Female   4   Under 12 2024-05-20
# 391                      NaN     14.0   Other   0   Under 12 2024-05-20
# 392                      NaN     14.0   Other   0   Under 12 2024-05-20
# 393                      NaN     14.0   Other   0   Under 12 2024-05-20
# 394                      NaN      NaN   Other   0   Under 12 2024-05-17
#
#                                           Action Taken       _id  \
# 182                        All referred to the clinic   10836792
# 183                        All referred to the clinic   10836792
# 184                        All referred to the clinic   10836792
# 185                        All referred to the clinic   10836792
# 186                        All referred to the clinic   10836792
# 187                        All referred to the clinic   10836792
# 188                        All referred to the clinic   10836792
# 189                        All referred to the clinic   10836792
# 190                        All referred to the clinic   10836792
# 368  It was cancelled the father of the pastor hap ...  10993166
# 369  It was cancelled the father of the pastor hap ...  10993166
# 370  It was cancelled the father of the pastor hap ...  10993166
# 371  Health education  was given  and she was advic...  10993167
# 372  Health education  was given  and she was advic...  10993167
# 373  Health education  was given  and she was advic...  10993167
# 374  Health education  was given  and she was advic...  10993167
# 375  Health education  was given  and she was advic...  10993167
# 376  Health education  was given  and she was advic...  10993167
# 377  Advised to remove nuisance and health educatio...  10993168
# 378  Advised to remove nuisance and health educatio...  10993168
# 379  Advised to remove nuisance and health educatio...  10993168
# 380  Advised to remove nuisance and health educatio...  10993168
# 381  Advised to remove nuisance and health educatio...  10993168
# 382  Advised to remove nuisance and health educatio...  10993168
# 383  Advised to remove nuisance and health educatio...  10993168
# 384  Advised to remove nuisance and health educatio...  10993168
# 385  Advised to remove nuisance and health educatio...  10993168
# 386  Advised to remove nuisance and health educatio...  10993168
# 387  Advised to remove nuisance and health educatio...  10993168
# 388  Advised to remove nuisance and health educatio...  10993168
# 389  Advised to remove nuisance and health educatio...  10993168
# 390  Advised to remove nuisance and health educatio...  10993168
# 391  Advised to remove nuisance and health educatio...  10993168
# 392  Advised to remove nuisance and health educatio...  10993168
# 393  Advised to remove nuisance and health educatio...  10993168
# 394            Went into the community to probe futher  10995698
#
#      affected_demographics_001._index
# 182                              3559
# 183                              3560
# 184                              3561
# 185                              3562
# 186                              3563
# 187                              3564
# 188                              3565
# 189                              3566
# 190                              3567
# 368                              3799
# 369                              3800
# 370                              3801
# 371                              3802
# 372                              3803
# 373                              3804
# 374                              3805
# 375                              3806
# 376                              3807
# 377                              3808
# 378                              3809
# 379                              3810
# 380                              3811
# 381                              3812
# 382                              3813
# 383                              3814
# 384                              3815
# 385                              3816
# 386                              3817
# 387                              3818
# 388                              3819
# 389                              3820
# 390                              3821
# 391                              3822
# 392                              3823
# 393                              3824
# 394                              3825
#
# [36 rows x 21 columns]

# %%
# Assign colors based on event type
import math
import folium
import pandas as pd
from IPython.display import display


# Assign colors based on event type
def get_color(event):
    colors = {
        'Diarrhoea': 'red',
        'Influenza-Like Illness': 'blue',
        'Rash': 'orange',
        'Environmental Hazard': 'purple',
        'STI Infections': 'grey',
        'Sudden Death of Unknown Cause': 'brown',
        'Suspected Malaria Case': 'lime',
        'Dog Bite': 'pink',
        'Ringworms': 'olive',
        'Suspected TB Case': 'gold',
        'Suspected Measles Case': 'crimson',
        'Suspected Case of Mumps': 'lightgreen',
        'Positive TB Case': 'darkslategrey',
        'Snake Bite': 'plum',
        'Unexplained illness': 'khaki',
        'Malaria Positive Case': 'green',
        'Suspected Scabies Case': 'skyblue',
    }
    return colors.get(event, 'black')


#Create Map

zim_map = folium.Map(location=[-19.0169211, 29.1549], zoom_start=7,tiles = "openstreetmap")

# add marker one by one on the map, and account for Mercator deformation
for index in df.itertuples():
    index_dict = index._asdict()
    local_deformation = math.cos(index.latitude * math.pi / 180)
    adjusted_radius = (index.affected) * local_deformation
    color = get_color(index.event)
    folium.CircleMarker(
        location=[index.latitude, index.longitude],  # Use dot notation to access attributes
        popup='{} ({:.1f})'.format(index.Location,index.affected), # Use dot notation to access attributes
        tooltip = f"Event Recorded: {index.event}, No of Affected: {index.affected}, Location: {index.Location}",
        radius=adjusted_radius,
        color=color,
        fill=True,
        fill_color=color
    ).add_to(zim_map)


# Add title to the map
title_html = '''
            # <h3 align="center" style="font-size:20px"><b> Zimbabwe Community Event-Based Surveillance Map</b></h3>
             #'''

# Add title with logos to the map
title_html = '''
    <div style="text-align:center;">
        <h3 style="font-size:25px;display:inline-block;vertical-align:middle;"><b>Zimbabwe Community Event-Based Surveillance Map</b></h3>
        <img src="https://i.postimg.cc/sxpkjwjj/GOZ.png" style="height:100px;vertical-align:middle;">
        <img src="https://i.postimg.cc/Rh7Zk72f/EN-Fundedbythe-EU-RGB-POS.png" style="height:100px;vertical-align:middle;">
        <img src="https://i.postimg.cc/xjwj94R2/oim-iom-seeklogo-com.png" style="height:100px;vertical-align:middle;">
        <img src="https://i.postimg.cc/MHnLb9fw/DTM.png" style="height:60px;vertical-align:middle;">

    </div>
    '''

# Add textbox at the bottom right corner
textbox_html = '''
    <div style="position: fixed; bottom: 10px; right: 10px; width: 250px; background-color: white; opacity:0.65; border: 0.5px solid black; padding: 10px; z-index: 1000;">
        <p style="margin: 0;">Source: IOM Zimbabwe | DTM, 2024</p>
        <p style="margin: 0;">Latest data uploaded 12 May 2024.</p>
    </div>
    '''
zim_map.get_root().html.add_child(folium.Element(textbox_html))


zim_map.get_root().html.add_child(folium.Element(title_html))

# Add legend
legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    left: 50px;
    width: 250px;
    height: 380px;
    border:2px solid grey;
    z-index:9999;
    font-size:14px;
    background-color:white;
    opacity: 0.85;
    ">
    <b>&nbsp; Legend</b><br>
    &nbsp; <i class="fa fa-circle" style="color:red"></i>&nbsp;Diarrhoea<br>
    &nbsp; <i class="fa fa-circle" style="color:blue"></i>&nbsp; Influenza-Type Illness<br>
    &nbsp; <i class="fa fa-circle" style="color:lime"></i>&nbsp; Suspected Malaria Case <br>
    &nbsp; <i class="fa fa-circle" style="color:green"></i>&nbsp; Malaria Positive Case<br>
    &nbsp; <i class="fa fa-circle" style="color:orange"></i>&nbsp; Rash<br>
    &nbsp; <i class="fa fa-circle" style="color:gold"></i>&nbsp; Suspected TB Case<br>
    &nbsp; <i class="fa fa-circle" style="color:darkslategrey"></i>&nbsp; Positive TB Case<br>
    &nbsp; <i class="fa fa-circle" style="color:lightgreen"></i>&nbsp; Suspected Case of Mumps<br>
    &nbsp; <i class="fa fa-circle" style="color:olive"></i>&nbsp; Ringworms<br>
    &nbsp; <i class="fa fa-circle" style="color:crimson"></i>&nbsp; Suspected Measles Case<br>
    &nbsp; <i class="fa fa-circle" style="color:purple"></i>&nbsp; Environmental Hazard<br>
    &nbsp; <i class="fa fa-circle" style="color:plum"></i>&nbsp; Snake Bite<br>
    &nbsp; <i class="fa fa-circle" style="color:pink"></i>&nbsp; Dog Bite<br>
    &nbsp; <i class="fa fa-circle" style="color:grey"></i>&nbsp; STI Infections<br>
    &nbsp; <i class="fa fa-circle" style="color:brown"></i>&nbsp; Sudden Death of Unknown Cause<br>
    &nbsp; <i class="fa fa-circle" style="color:khaki"></i>&nbsp; Unexplained illness<br>
    &nbsp; <i class="fa fa-circle" style="color:skyblue"></i>&nbsp; Suspected Scabies Case<br>
</div>
'''
zim_map.get_root().html.add_child(folium.Element(legend_html))





# Display the map
display(zim_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1ea31e9efcbebba9d56c8a79e9cf74d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed; bottom: 10px; right: 10px; width: 250px; background-color: white; opacity:0.65; border: 0.5px solid black; padding: 10px; z-index: 1000;&quot;&gt;
#         &lt;p style=&quot;margin: 0;&quot;&gt;Source: IOM Zimbabwe | DTM, 2024&lt;/p&gt;
#         &lt;p style=&quot;margin: 0;&quot;&gt;Latest data uploaded 12 May 2024.&lt;/p&gt;
#     &lt;/div&gt;
#
#
#     &lt;div style=&quot;text-align:center;&quot;&gt;
#         &lt;h3 style=&quot;font-size:25px;display:inline-block;vertical-align:middle;&quot;&gt;&lt;b&gt;Zimbabwe Community Event-Based Surveillance Map&lt;/b&gt;&lt;/h3&gt;
#         &lt;img src=&quot;https://i.postimg.cc/sxpkjwjj/GOZ.png&quot; style=&quot;height:100px;vertical-align:middle;&quot;&gt;
#         &lt;img src=&quot;https://i.postimg.cc/Rh7Zk72f/EN-Fundedbythe-EU-RGB-POS.png&quot; style=&quot;height:100px;vertical-align:middle;&quot;&gt;
#         &lt;img src=&quot;https://i.postimg.cc/xjwj94R2/oim-iom-seeklogo-com.png&quot; style=&quot;height:100px;vertical-align:middle;&quot;&gt;
#         &lt;img src=&quot;https://i.postimg.cc/MHnLb9fw/DTM.png&quot; style=&quot;height:60px;vertical-align:middle;&quot;&gt;
#
#     &lt;/div&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     left: 50px;
#     width: 250px;
#     height: 380px;
#     border:2px solid grey;
#     z-index:9999;
#     font-size:14px;
#     background-color:white;
#     opacity: 0.85;
#     &quot;&gt;
#     &lt;b&gt;&amp;nbsp; Legend&lt;/b&gt;&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:red&quot;&gt;&lt;/i&gt;&amp;nbsp;Diarrhoea&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:blue&quot;&gt;&lt;/i&gt;&amp;nbsp; Influenza-Type Illness&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:lime&quot;&gt;&lt;/i&gt;&amp;nbsp; Suspected Malaria Case &lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:green&quot;&gt;&lt;/i&gt;&amp;nbsp; Malaria Positive Case&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:orange&quot;&gt;&lt;/i&gt;&amp;nbsp; Rash&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:gold&quot;&gt;&lt;/i&gt;&amp;nbsp; Suspected TB Case&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:darkslategrey&quot;&gt;&lt;/i&gt;&amp;nbsp; Positive TB Case&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:lightgreen&quot;&gt;&lt;/i&gt;&amp;nbsp; Suspected Case of Mumps&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:olive&quot;&gt;&lt;/i&gt;&amp;nbsp; Ringworms&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:crimson&quot;&gt;&lt;/i&gt;&amp;nbsp; Suspected Measles Case&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:purple&quot;&gt;&lt;/i&gt;&amp;nbsp; Environmental Hazard&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:plum&quot;&gt;&lt;/i&gt;&amp;nbsp; Snake Bite&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:pink&quot;&gt;&lt;/i&gt;&amp;nbsp; Dog Bite&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:grey&quot;&gt;&lt;/i&gt;&amp;nbsp; STI Infections&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:brown&quot;&gt;&lt;/i&gt;&amp;nbsp; Sudden Death of Unknown Cause&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:khaki&quot;&gt;&lt;/i&gt;&amp;nbsp; Unexplained illness&lt;br&gt;
#     &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:skyblue&quot;&gt;&lt;/i&gt;&amp;nbsp; Suspected Scabies Case&lt;br&gt;
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1ea31e9efcbebba9d56c8a79e9cf74d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1ea31e9efcbebba9d56c8a79e9cf74d = L.map(
#                 &quot;map_a1ea31e9efcbebba9d56c8a79e9cf74d&quot;,
#                 {
#                     center: [-19.0169211, 29.1549],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4422ed2cde58d17e4d6dc87fe2a6ae63 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a1ea31e9efcbebba9d56c8a79e9cf74d);
#
#
#             var circle_marker_ad08b9ef281bc4fde917a6324804cb57 = L.circleMarker(
#                 [-20.20939, 28.5359438],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quo

# %%
#save map as html
zim_map.save('May CEBS_2024.html')
